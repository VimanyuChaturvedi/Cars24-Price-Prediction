# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cars = pd.read_csv('car_data.csv') #retrieving file in pandas

# %%
df_cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df_cars['Year'].min() #printing min year for the model year #check
# Out:
# 2003

# %%
df_cars['Year'].max() #Printing max year for the model year #check
# Out:
# 2018

# %%
df_cars[df_cars['Year'] == df_cars['Year'].max()] #printing the detail/row which has the max year #check
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner
# 5      Dealer       Manual      0

# %% [markdown]
# # Condition 1 - Cars available in the Dataset on the basis of below conditions
# ## Max old 5 years, Petrol, Selling price < 2.2 lakhs, kms driven < 7000

# %% [markdown]
# ### CONDITION 1.a

# %%
df_cars = df_cars[df_cars['Year'] >= 2017] #condition 1 - filtering cars not older than 5 years 
df_cars
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 2                         ciaz  2017           7.25           9.85
# 5                vitara brezza  2018           9.25           9.83
# 10                    alto 800  2017           2.85           3.60
# 21                       ignis  2017           4.90           5.71
# 27                       swift  2017           6.00           6.49
# 49                        ciaz  2017           7.75           9.29
# 52                      innova  2017          18.00          19.77
# 64                    fortuner  2017          33.00          36.23
# 66                      innova  2017          19.75          23.15
# 82                      innova  2017          23.00          25.39
# 97               corolla altis  2017          17.00          18.64
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# ...

# %% [markdown]
# ### CONDITION 1.b

# %%
df_cars = df_cars[df_cars['Selling_Price'] <= 2.2] #condition 2 - filtering cars with max selling price 2.2 lakhs
df_cars
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# 109  Royal Enfield Classic 350  2017           1.20           1.47
# 126          Bajaj Avenger 220  2017           0.90           0.95
# 128       Honda CB Hornet 160R  2017           0.80           0.87
# 129          Yamaha FZ S V 2.0  2017           0.78           0.84
# 130       Honda CB Hornet 160R  2017           0.75           0.87
# 132          Bajaj Avenger 220  2017           0.75           0.95
# 134         TVS Apache RTR 160  2017           0.65           0.81
# 155            Honda Activa 4G  2017           0.48           0.51
# 156                 TVS Sport   2017           0.48           0.52
# ...

# %% [markdown]
# ### CONDITION 1.c

# %%
df_cars = df_cars[df_cars['Kms_Driven'] <= 7000] #condition 3 - filtering cars with max kilometers driven is 7000km
df_cars
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# 126          Bajaj Avenger 220  2017           0.90           0.95
# 128       Honda CB Hornet 160R  2017           0.80           0.87
# 129          Yamaha FZ S V 2.0  2017           0.78           0.84
# 132          Bajaj Avenger 220  2017           0.75           0.95
# 155            Honda Activa 4G  2017           0.48           0.51
# 159            Honda Activa 4G  2017           0.45           0.51
# 173                  Activa 4g  2017           0.40           0.51
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 101        1400    Petrol  Individual       Manual      0
# ...

# %%
df_cars = pd.read_csv('car_data.csv') #reseting the dataset

# %%
df_cars['Selling_Price'].mean() #averaging out the selling price for all the cars
# Out:
# 4.661295681063127

# %%
df_cars = df_cars[df_cars['Fuel_Type'] == 'Petrol'] #Updating the dataset with petrol cars only

# %%
df_cars['Selling_Price'].mean() #averaging out the selling price for petrol cars only
# Out:
# 3.2641841004184085

# %%
df_cars = df_cars[df_cars['Fuel_Type'] == 'Diesel'] #Updating the dataset with diesel cars only

# %%
df_cars['Selling_Price'].mean() #averaging out the selling price for diesel cars only
# Out:
# nan

# %%
df_cars = pd.read_csv('car_data.csv') #reseting the dataset

# %% [markdown]
# ### CONDITION SELECTING AUTOMATIC FORTUNER CARS LESS THAN 18.75 LAKHS

# %%
df_fortuner = df_cars[df_cars['Car_Name'] == 'fortuner']              #creating new variable df_fortuner
df_fortuner = df_fortuner[df_fortuner['Transmission'] == 'Automatic']
df_fortuner = df_fortuner[df_fortuner['Selling_Price'] <= 18.75]
df_fortuner
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50  fortuner  2012          14.90          30.61      104707    Diesel
# 53  fortuner  2013          16.00          30.61      135000    Diesel
# 62  fortuner  2014          18.75          35.96       78000    Diesel
# 79  fortuner  2012          14.50          30.61       89000    Diesel
#
#    Seller_Type Transmission  Owner
# 50      Dealer    Automatic      0
# 53  Individual    Automatic      0
# 62      Dealer    Automatic      0
# 79      Dealer    Automatic      0

# %%
df_cars = pd.read_csv('car_data.csv') #reseting the dataset

# %%
df_cars.drop_duplicates() #this will drop all the duplicate rows
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df_cars = df_cars.drop_duplicates(subset = ["Car_Name"]) 
#this will drop all the duplicate cars and will keep the data for one car only
df_cars
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 215    verna  2012           4.50           9.40       36100    Petrol
# 251     city  2013           5.00           9.90       56701    Petrol
# 252     brio  2015           5.40           6.82       31427    Petrol
# 259    amaze  2014           3.90           7.00       36054    Petrol
# 263     jazz  2016           6.60           7.70       16002    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
from matplotlib.pyplot import figure
fig, ax = plt.subplots() # Create the figure and axes object
#df_cars.xticklabels
#df_cars.set_xticklabels(['Car_Name'])
#figsize = plt.subplots()
#fig = plt.subplots(figsize =(18, 13))
df_cars.plot(x = 'Car_Name', y = 'Selling_Price', ax = ax) # Plot the first x and y axes:

df_cars.plot(x = 'Car_Name', y = 'Present_Price', ax = ax)
#figure(figsize=(16, 10), dpi=80)
#plt.figure(figsize=(20, 10), dpi=150)
#df_cars.set_xticklabels(xticklabels, rotation = 45)
# Plot the second x and y axes. By secondary_y=True a second y-axis is requested:
# Out:
# <AxesSubplot:xlabel='Car_Name'>

# %%
    plt.bar(df_cars['Car_Name'],values_count().index, df_cars['Selling_Price'],values_count().values)
print(plt.bar)

#plt.xlabel("Car Name")
#plt.ylabel("Selling Price")
#plt.title("Car vs Selling Price")
#plt.show()

#plt.bar(x = 'Car_Name', y = 'Selling_Price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16036/2782449477.py in <module>
# ----> 1 plt.bar(df_cars['Car_Name'],values_count().index, df_cars['Selling_Price'],values_count().values)
#       2 print(plt.bar)
#       3
#       4 #plt.xlabel("Car Name")
#       5 #plt.ylabel("Selling Price")
#
# NameError: name 'values_count' is not defined

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots() # Create the figure and axes object
#df_cars.xticklabels
#df_cars.set_xticklabels(['Car_Name'])
#figsize = plt.subplots()
#fig = plt.subplots(figsize =(18, 13))
df_cars.plot(x = 'Car_Name', y = 'Selling_Price', c='r', label='Selling Price', ax=ax, figsize=(12, 7)) # Plot the first x and y axes:

df_cars.plot(x = 'Car_Name', y = 'Present_Price', c='b', label='Present Price', ax=ax)

ax.set_xticks(map(str, df_cars['Car_Name'].value_counts().index))

#figure(figsize=(16, 10), dpi=80)
#plt.figure(figsize=(20, 10), dpi=150)
#df_cars.set_xticklabels(xticklabels, rotation = 45)
# Plot the second x and y axes. By secondary_y=True a second y-axis is requested:

# %%
df_cars['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
df_cars['Car_Name'].value_counts().index
# Out:
# Index(['city', 'corolla altis', 'verna', 'fortuner', 'brio', 'ciaz', 'innova',
#        'i20', 'grand i10', 'jazz', 'amaze', 'Royal Enfield Classic 350',
#        'ertiga', 'eon', 'sx4', 'alto k10', 'i10', 'swift', 'Bajaj Pulsar 150',
#        'Royal Enfield Thunder 350', 'ritz', 'wagon r', 'etios liva', 'dzire',
#        'xcent', 'etios cross', 'Royal Enfield Thunder 500',
#        'TVS Apache RTR 160', 'Yamaha FZ S V 2.0', 'creta',
#        'Honda CB Hornet 160R', 'etios g', 'Bajaj Avenger 220',
#        'Bajaj Pulsar NS 200', 'Bajaj Discover 125', 'Bajaj Pulsar 220 F',
#        'TVS Apache RTR 180', 'Yamaha FZ  v 2.0', 'Honda Activa 4G',
#        'Hero Extreme', 'Honda CB twister', 'Hero Splender iSmart', 'Activa 3g',
#        'Hero Passion Pro', 'Honda CB Shine', 'Bajaj Avenger 220 dtsi',
#        'Honda CBR 150', 'elantra', 'Royal Enfield Classic 500', 'KTM RC200',
#        'Honda Karizma', 'Bajaj  ct 100', 'Hero  Ignitor Disc', 'TVS Jupyter',
# ...
